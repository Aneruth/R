# %%
vec <- c(2L,4L,15L,12L,345L)
vec1 <- c(4,5,2,35)
vec2 <- c('a','b','c')

# %%
print(vec)
print(vec1)
print(vec2)
# Out:
# [1]   2   4  15  12 345
# [1]  4  5  2 35
# [1] "a" "b" "c"

# %% [markdown]
# # To print all odd numbers
# odd <- seq(1,10,2)
# odd

# %% [markdown]
# ## To print Evene numbers

# %%
## Method 1
eve <- seq(0,10,2)
eve
# Out:
# [1]  0  2  4  6  8 10

# %%
## Method 2
for(i in 1:10){
  if(i %% 2 ==0){
    print(i)
  }
}
# Out:
# [1] 2
# [1] 4
# [1] 6
# [1] 8
# [1] 10
